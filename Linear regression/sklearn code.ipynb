# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
dfx=pd.read_csv('x_values.csv').values
dfy=pd.read_csv('y_values.csv').values
x=dfx.reshape((-1,1))
y=dfy.reshape((-1,1))
plt.style.use('dark_background')
plt.scatter(x,y,label='training data')
plt.legend()
plt.show()

# %%
m=LinearRegression()
m.fit(x,y)
output=m.predict(x)
bias=m.intercept_   #intercept
coeff=m.coef_       #slope
print(bias)
print(coeff)
# Out:
# [98.968]
# [[2.6104]]

# %%
m.score(x,y)
plt.style.use('dark_background')
plt.scatter(x,y,label='training data')
plt.plot(x,output,color='yellow',label='prediction')
plt.legend()
plt.show()
